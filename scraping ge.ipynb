# %%
import re
import requests
from bs4 import BeautifulSoup as bs

# %%
url2 = 'https://ge.globo.com/futebol/brasileirao-serie-a/' 
content = requests.get(url2)
print(content.status_code)

soup = bs(content.text, 'html')
print(soup.prettify()[0:1000])
# Out:
# 200
# <!DOCTYPE HTML>
# <html lang="pt-br">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge,chrome=1" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <script id="CDA_AAS" type="text/javascript">
#    window.cdaaas = window.cdaaas || {};
#   window.cdaaas.SETTINGS = window.cdaaas.SETTINGS || {};
#   window.cdaaas.PAGE_ANALYTICS_DATA = {"channel":"desktop","contentId":"d1a37fa4-e948-43a6-ba53-ab24ab3a45b1","contentType":[],"serviceWorker":true};
#   </script>
#   <!-- Filers GCOM -->
#   <link href="https://s.glbimg.com" rel="preconnect"/>
#   <link href="https://s.glbimg.com" rel="dns-prefetch"/>
#   <link href="https://s2.glbimg.com" rel="preconnect"/>
#   <link href="https://s2.glbimg.com" rel="dns-prefetch"/>
#   <link href="https://s3.glbimg.com" rel="preconnect"/>
#   <link href="https://s3.glbimg.com" rel="dns-prefetch"/>
#   <!-- Filers GCOM -->
#   <!-- Globo ID -->
#   <link href="https://cocoon.globo.com" rel="preconnect"/>
#   <link href="https:/

# %%
tag = soup.findAll('script', attrs = {'id' : 'scriptReact'})[0].string
tabela = re.findall('const classificacao = (.*?);', tag)[0]
tabela
# Out:
# '{"classificacao":[{"aproveitamento":74.5,"derrotas":3,"empates":2,"equipe_id":282,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/03\\/10\\/atletico-mg.svg","faixa_classificacao":{"cor":"#0000ff"},"faixa_classificacao_cor":"#0000ff","gols_contra":12,"gols_pro":26,"jogos":17,"nome_popular":"Atl\\u00e9tico-MG","ordem":1,"pontos":38,"saldo_gols":14,"sigla":"CAM","ultimos_jogos":["v","v","v","v","e"],"variacao":0,"vitorias":12},{"aproveitamento":62.7,"derrotas":5,"empates":2,"equipe_id":275,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/07\\/06\\/Palmeiras.svg","faixa_classificacao":{"cor":"#0000ff"},"faixa_classificacao_cor":"#0000ff","gols_contra":19,"gols_pro":27,"jogos":17,"nome_popular":"Palmeiras","ordem":2,"pontos":32,"saldo_gols":8,"sigla":"PAL","ultimos_jogos":["v","e","d","d","d"],"variacao":0,"vitorias":10},{"aproveitamento":62.7,"derrotas":3,"empates":5,"equipe_id":356,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2021\\/04\\/13\\/fortaleza.svg","faixa_classificacao":{"cor":"#0000ff"},"faixa_classificacao_cor":"#0000ff","gols_contra":16,"gols_pro":27,"jogos":17,"nome_popular":"Fortaleza","ordem":3,"pontos":32,"saldo_gols":11,"sigla":"FOR","ultimos_jogos":["v","d","v","e","e"],"variacao":0,"vitorias":9},{"aproveitamento":60.8,"derrotas":2,"empates":7,"equipe_id":280,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2021\\/06\\/28\\/bragantino.svg","faixa_classificacao":{"cor":"#0000ff"},"faixa_classificacao_cor":"#0000ff","gols_contra":18,"gols_pro":28,"jogos":17,"nome_popular":"Bragantino","ordem":4,"pontos":31,"saldo_gols":10,"sigla":"BGT","ultimos_jogos":["d","v","e","d","v"],"variacao":0,"vitorias":8},{"aproveitamento":62.2,"derrotas":5,"empates":1,"equipe_id":262,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/04\\/10\\/Flamengo-2018.svg","faixa_classificacao":{"cor":"#00ffff"},"faixa_classificacao_cor":"#00ffff","gols_contra":16,"gols_pro":28,"jogos":15,"nome_popular":"Flamengo","ordem":5,"pontos":28,"saldo_gols":12,"sigla":"FLA","ultimos_jogos":["v","v","d","v","e"],"variacao":0,"vitorias":9},{"aproveitamento":47.1,"derrotas":5,"empates":6,"equipe_id":264,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/09\\/30\\/Corinthians.svg","faixa_classificacao":{"cor":"#00ffff"},"faixa_classificacao_cor":"#00ffff","gols_contra":15,"gols_pro":16,"jogos":17,"nome_popular":"Corinthians","ordem":6,"pontos":24,"saldo_gols":1,"sigla":"COR","ultimos_jogos":["v","d","e","v","v"],"variacao":5,"vitorias":6},{"aproveitamento":47.1,"derrotas":5,"empates":6,"equipe_id":373,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2020\\/07\\/02\\/atletico-go-2020.svg","faixa_classificacao":{"cor":"#008000"},"faixa_classificacao_cor":"#008000","gols_contra":17,"gols_pro":15,"jogos":17,"nome_popular":"Atl\\u00e9tico-GO","ordem":7,"pontos":24,"saldo_gols":-2,"sigla":"ACG","ultimos_jogos":["v","e","e","v","e"],"variacao":0,"vitorias":6},{"aproveitamento":47.1,"derrotas":3,"empates":9,"equipe_id":354,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/10\\/10\\/ceara.svg","faixa_classificacao":{"cor":"#008000"},"faixa_classificacao_cor":"#008000","gols_contra":17,"gols_pro":19,"jogos":17,"nome_popular":"Cear\\u00e1","ordem":8,"pontos":24,"saldo_gols":2,"sigla":"CEA","ultimos_jogos":["e","v","e","d","e"],"variacao":0,"vitorias":5},{"aproveitamento":47.9,"derrotas":7,"empates":2,"equipe_id":293,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/09\\/09\\/Athletico-PR.svg","faixa_classificacao":{"cor":"#008000"},"faixa_classificacao_cor":"#008000","gols_contra":19,"gols_pro":22,"jogos":16,"nome_popular":"Athletico-PR","ordem":9,"pontos":23,"saldo_gols":3,"sigla":"CAP","ultimos_jogos":["v","d","d","d","d"],"variacao":-3,"vitorias":7},{"aproveitamento":43.1,"derrotas":5,"empates":7,"equipe_id":285,"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/org ...

# %%
jogos = re.findall('const listaJogos = (.*?);', tag)[0]
jogos
# Out:
# '[{"data_realizacao":"2021-08-28T17:00","equipes":{"mandante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/03\\/11\\/sport.svg","id":292,"nome_popular":"Sport","sigla":"SPT"},"visitante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2021\\/06\\/21\\/CHAPECOENSE-2018.svg","id":315,"nome_popular":"Chapecoense","sigla":"CHA"}},"hora_realizacao":"17:00","id":270488,"placar_oficial_mandante":null,"placar_oficial_visitante":null,"placar_penaltis_mandante":null,"placar_penaltis_visitante":null,"sede":{"nome_popular":"Ilha do Retiro"},"transmissao":null},{"data_realizacao":"2021-08-28T19:00","equipes":{"mandante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/03\\/12\\/santos.svg","id":277,"nome_popular":"Santos","sigla":"SAN"},"visitante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/04\\/10\\/Flamengo-2018.svg","id":262,"nome_popular":"Flamengo","sigla":"FLA"}},"hora_realizacao":"19:00","id":270482,"placar_oficial_mandante":null,"placar_oficial_visitante":null,"placar_penaltis_mandante":null,"placar_penaltis_visitante":null,"sede":{"nome_popular":"Vila Belmiro"},"transmissao":null},{"data_realizacao":"2021-08-28T21:00","equipes":{"mandante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/07\\/06\\/Palmeiras.svg","id":275,"nome_popular":"Palmeiras","sigla":"PAL"},"visitante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/09\\/09\\/Athletico-PR.svg","id":293,"nome_popular":"Athletico-PR","sigla":"CAP"}},"hora_realizacao":"21:00","id":270484,"placar_oficial_mandante":null,"placar_oficial_visitante":null,"placar_penaltis_mandante":null,"placar_penaltis_visitante":null,"sede":{"nome_popular":"Allianz Parque"},"transmissao":null},{"data_realizacao":"2021-08-28T21:00","equipes":{"mandante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/03\\/12\\/gremio.svg","id":284,"nome_popular":"Gr\\u00eamio","sigla":"GRE"},"visitante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/09\\/30\\/Corinthians.svg","id":264,"nome_popular":"Corinthians","sigla":"COR"}},"hora_realizacao":"21:00","id":270485,"placar_oficial_mandante":null,"placar_oficial_visitante":null,"placar_penaltis_mandante":null,"placar_penaltis_visitante":null,"sede":{"nome_popular":"Arena do Gr\\u00eamio"},"transmissao":null},{"data_realizacao":"2021-08-29T11:00","equipes":{"mandante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/02\\/28\\/America-MG-VERDE-fev2019-01.svg","id":327,"nome_popular":"Am\\u00e9rica-MG","sigla":"AME"},"visitante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2019\\/10\\/10\\/ceara.svg","id":354,"nome_popular":"Cear\\u00e1","sigla":"CEA"}},"hora_realizacao":"11:00","id":270486,"placar_oficial_mandante":null,"placar_oficial_visitante":null,"placar_penaltis_mandante":null,"placar_penaltis_visitante":null,"sede":{"nome_popular":"Independ\\u00eancia"},"transmissao":null},{"data_realizacao":"2021-08-29T16:00","equipes":{"mandante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2021\\/04\\/29\\/Juventude-2021-01.svg","id":286,"nome_popular":"Juventude","sigla":"JUV"},"visitante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/03\\/11\\/sao-paulo.svg","id":276,"nome_popular":"S\\u00e3o Paulo","sigla":"SAO"}},"hora_realizacao":"16:00","id":270490,"placar_oficial_mandante":null,"placar_oficial_visitante":null,"placar_penaltis_mandante":null,"placar_penaltis_visitante":null,"sede":{"nome_popular":"Alfredo Jaconi"},"transmissao":null},{"data_realizacao":"2021-08-29T18:15","equipes":{"mandante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2020\\/07\\/02\\/atletico-go-2020.svg","id":373,"nome_popular":"Atl\\u00e9tico-GO","sigla":"ACG"},"visitante":{"escudo":"https:\\/\\/s.glbimg.com\\/es\\/sde\\/f\\/organizacoes\\/2018\\/03\\/11\\/internac ...
